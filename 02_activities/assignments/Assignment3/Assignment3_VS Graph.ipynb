# %%
import pandas as pd

hospcovid = pd.read_csv(r"C:\Users\shaum\Downloads\d1199d1b-dc82-4e63-bb80-5c715e97a127.csv")
print(hospcovid.head())
# Out:
#     _id                 date  hosp_for_covid  hosp_other_conditions  \
# 0  1027  2022-01-08T00:00:00          0.5302                 0.4698
# 1  1028  2022-01-09T00:00:00          0.5395                 0.4605
# 2  1029  2022-01-10T00:00:00          0.5468                 0.4532
# 3  1030  2022-01-11T00:00:00          0.5450                 0.4550
# 4  1031  2022-01-12T00:00:00          0.5277                 0.4723
#
#    icu_for_covid  icu_other_conditions
# 0         0.7955                0.2045
# 1         0.8279                0.1721
# 2         0.8307                0.1693
# 3         0.8198                0.1802
# 4         0.8027                0.1973

# %%
import matplotlib.pyplot as plt
import pandas as pd

x = hospcovid['date']
y1= hospcovid["hosp_for_covid"]
y2= hospcovid["icu_for_covid"]


fig, ax = plt.subplots(figsize=(7,3))
ax.set_title('Covid-19 Hospitalization')
ax.plot(x,y1, label ="hosp_for_covid",  color = 'blue')
ax.plot(x,y2, label = "icu_for_covid", color = 'red')
ax.legend(loc='upper left',
          bbox_to_anchor = (1,1),
          frameon = True,
          fontsize = 12,
          shadow = True)
