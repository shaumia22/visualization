# %% [markdown]
# visualization #1:
# info = number of people who were killed in 2018 and the number of years lost as a result of the gun violence
# this is not objective because it is positioned to show the number of years stolen.
#
# visualization #2:
# info = shows the # of gun incidents over a range of years
# this is neutral - shows the number of incidents and leaves it there
